# %% [markdown]
# 프로젝트 제목: 인구수에 의한 집값 분석
#
# 1. 데이터셋 소개 및 분석 목적:
# - 데이터셋 1: 행정안전부_지역별(시도/시군구/읍면동) 연령별 주민등록 인구현황 데이터셋 (전국의 시도 연령별 주민 인구수)
#
# - 데이터셋 2: 한국부동산원_공동주택 실거래가격지수_아파트_월별 지역별 매매 데이터셋 (전국의 시도 아파트 월별 매매 가격)
#
# - 분석 목적: 다른 지역들보다 수도권의 집값 상승세가 높은 이유가 궁금했습니다.
#
# 2. 데이터셋 분석 방법:
# - 데이터 전처리: 원하는 지역을 선택한 후 각 지역의 1월과 7월의 집값과 인구수를 배열에 넣어 matplotlib으로 그래프를 작성할 생각입니다.
#
# - 데이터 시각화: 그래프는 선그래프를 사용할 생각입니다.
#
# - 데이터 분석: 지역의 인구수와 집값을 비교하는 식으로 데이터 분석을 할 생각입니다. 시간이 남는다면 다른 추가적인 작업들도 해보도록 노력해보겠습니다.
#
# 3. 예상 결과:
# - 가설: 해당 지역의 인구수가 증가할수록 수요가 많아지기 때문에 아파트 가격이 증가할거라고 가설을 세웠습니다.
#
# - 예상 결과: 집값은 물가 상승으로 인해 매년 오르겠지만 수도권에 사람들이 많이 몰리기 때문에 수도권의 집값이 많이 올라가듯이 사람이 줄어드는 곳은 소폭 증가하고 사람이 몰리는 곳은 대폭 증가할것이라고 생각했습니다.
#
# 4. 일정 계획:
# - 데이터 수집 및 전처리: 5월 31일 ~ 6월 2일
#
# - 데이터 시각화 및 분석: 6월 3일 ~ 6월 7일
#
# - 보고서 작성: 6월 8일 ~ 6월 12일
#
# 5. 프로젝트 멤버:
# - 멤버 1: 202301777 정성윤, 전부
